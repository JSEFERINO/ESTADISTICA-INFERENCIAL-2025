# %% [markdown]
# <a href="https://colab.research.google.com/github/JSEFERINO/ESTADISTICA-INFERENCIAL-2025/blob/main/VIDEOS_Y_LABORATORIOS_2025_Estad%C3%ADstica_UTB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pynacl
from nacl import * # Keep this if you actually intend to use an obscure package named 'nacal'
from IPython.display import YouTubeVideo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 8.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# # **LABORATORIO1 - - Datos y Recolección de Datos2025**
# ## **https://forms.gle/XGZBGAGZYZa3QA3f6**

# %% [markdown]
# # **LABORATORIO 2 EN POWER BI**

# %%
YouTubeVideo('c9rrAcSwHrs')

# %% [markdown]
# # **Laboratorio 3  Limpieza de Datos en Power BI**

# %%
YouTubeVideo('FDxjdcE3jng')

# %% [markdown]
# # **LABORATORIO 4  - Parte 1:  EXCEL - Muestreo de medias y varianzas**

# %%
YouTubeVideo('fA3B7euqFZA')

# %% [markdown]
# # **LABORATORIO 4  - Parte 2:  Colab: Python - Muestreo de medias y varianzas**

# %%
YouTubeVideo('AzCOKCAGZ_o')

# %% [markdown]
# # **Laboratorio 5. Primera Parte de Examen parcial - 25%**
# + Mis apreciados estudiantes, saludos. Lee con Atención para Evitar confusión.
#
# + Esta es una Actividad que puede desarrollar cualquier persona que quiera aprender un poco de Estadística usando Ciencia de datos.
# + En un archivo .text adjunto, aparece el paso a paso a seguir para el desarrollo del Laboratorio 5 donde trataremos el tema de   Variables Cualitativas y Gráficos y su interpretación
# + El Video preparado para realizar el Laboratorio lo encuentras en la dirección: https://youtu.be/45boYA_GcWc
# + Debes realizar todo lo que te pida el video y vas a intervenir en los pasos 11 y 12 como dice la guía arriba.
# + Los entregables son los siguientes:
# + + Me debes compartir el colab o enviarme el pdf al correo juliohurtado210307@gmail.com
# + + Cuando termines el Colab ingresa al link siguiente para ver cuanto aprendiste de la actividad del colab  https://forms.gle/zWtV6wdkwKtsmNGDA
# + El Total de Puntos de la Actividad correspondientes a la Semana 5 es de 150 PUNTOS.
# + En la clase de 2 horas realizaremos la segunda Parte del parcial

# %%
YouTubeVideo('45boYA_GcWc')  # ejecute este bloque de código para ver el vídeo

# %% [markdown]
# # **Laboratorio 6  Estadistica con Colab   Parte 1**

# %%
YouTubeVideo('eiLm8kaH7-E')  # ejecute este bloque de código para ver el vídeo

# %% [markdown]
# # **Laboratorio 6  Parte 2  Gráficos de Variables cuantitativas**

# %%
YouTubeVideo('38EP0EhAqcE')  # ejecute este bloque de código para ver el vídeo

# %% [markdown]
# # **Laboratorio 7 Análisis de una Variable Parte 1**

# %%
YouTubeVideo('f2ZNjjSMf9A')  # ejecute este bloque de código para ver el vídeo

# %% [markdown]
# # **Lab. 7. Parte 2 - Analisis de subgrupos**

# %%
YouTubeVideo('0OCPLcwSPn8')  # ejecute este bloque de código para ver el vídeo

# %% [markdown]
# # **Laboratorio 15  La Distribución Normal**

# %%
# @title **13 nov 2024**
YouTubeVideo('yElblhhwiiE')

# %% [markdown]
# # **Curso de Ciencia de Datos Para Docebtes**

# %%
# @title **14 nov 2024**
YouTubeVideo('PGZ7NbNwiAA')

# %%
# @title **13 nov 2024**
YouTubeVideo('Z2O5iRkD-B8')

# %%
# @title **7 nov 2024**
YouTubeVideo('J5Afo4Asb8I')

# %%
# @title **6 nov 2024**
YouTubeVideo('gwMRu5_4CRk')

# %%
# @title **6 nov 2024**
YouTubeVideo('tOd3-0-0-PM')

# %% [markdown]
# # **Semana 3   Clase 1 G8  Curso  Ciencia de Datos para Docentes**

# %%
# @title **6 nov 2024**
YouTubeVideo('D_vBXfYB9Lw')

# %% [markdown]
# # **Semana 3   Clase 2 G8  Curso  Ciencia de Datos para Docentes**

# %%
# @title **6 nov 2024**
YouTubeVideo('Pvo14w0bHAQ')

# %% [markdown]
# Europa
# University of Cambridge (Reino Unido)
#
# Ofrece cursos de pensamiento cuantitativo y matemáticas aplicadas en programas de ciencias sociales y economía.
#
# University of Oxford (Reino Unido)
#
# Imparte cursos de razonamiento cuantitativo en programas de economía, filosofía y ciencias políticas.
#
# ETH Zurich (Suiza)
#
# Ofrece cursos de matemáticas aplicadas y razonamiento cuantitativo en programas de ingeniería y ciencias.
#
# London School of Economics and Political Science (LSE) (Reino Unido)
#
# Incluye cursos de métodos cuantitativos en programas de economía y ciencias sociales.
#
# University of Amsterdam (Países Bajos)
#
# Ofrece cursos de razonamiento cuantitativo en programas de psicología y ciencias sociales.
#
# Asia
# National University of Singapore (NUS) (Singapur)
#
# Imparte cursos de razonamiento cuantitativo en programas de negocios, economía y ciencias sociales.
#
# University of Tokyo (Japón)
#
# Ofrece cursos de matemáticas aplicadas y razonamiento cuantitativo en programas de ingeniería y ciencias.
#
# Tsinghua University (China)
#
# Incluye cursos de métodos cuantitativos en programas de economía y administración de empresas.
#
# Indian Institute of Technology (IIT) (India)
#
# Ofrece cursos de razonamiento cuantitativo en programas de ingeniería y ciencias.
#
# Seoul National University (Corea del Sur)
#
# Imparte cursos de pensamiento cuantitativo en programas de negocios y ciencias sociales.
#
# América Latina
# Universidad Nacional Autónoma de México (UNAM) (México)
#
# Ofrece cursos de razonamiento cuantitativo en programas de economía, ingeniería y ciencias sociales.
#
# Universidad de Buenos Aires (UBA) (Argentina)
#
# Incluye cursos de métodos cuantitativos en programas de economía y administración.
#
# Pontificia Universidad Católica de Chile (UC) (Chile)
#
# Imparte cursos de razonamiento cuantitativo en programas de ingeniería y negocios.
#
# Universidad de los Andes (Colombia)
#
# Ofrece cursos de pensamiento cuantitativo en programas de economía y ciencias sociales.
#
# Instituto Tecnológico de Monterrey (ITESM) (México)
#
# Incluye cursos de razonamiento cuantitativo en programas de negocios y ingeniería.
#
# Estados Unidos
# Harvard University (Massachusetts)
#
# Ofrece cursos de razonamiento cuantitativo en programas de educación general y ciencias sociales.
#
# Stanford University (California)
#
# Imparte cursos de pensamiento cuantitativo en programas de negocios y ciencias de la computación.
#
# Massachusetts Institute of Technology (MIT) (Massachusetts)
#
# Ofrece cursos de matemáticas aplicadas y razonamiento cuantitativo en programas de ingeniería y ciencias.
#
# University of Chicago (Illinois)
#
# Incluye cursos de métodos cuantitativos en programas de economía y ciencias sociales.
#
# Columbia University (Nueva York)
#
# Imparte cursos de razonamiento cuantitativo en programas de negocios y ciencias políticas.
#
# Nota:
# El nombre específico del curso puede variar entre instituciones. Algunas universidades lo llaman "Quantitative Reasoning", "Quantitative Methods", "Mathematical Reasoning" o "Applied Mathematics". Te recomiendo revisar los planes de estudio de cada universidad para confirmar la disponibilidad de estos cursos.
#
# Me puedes hacer una revisión general de las temáticas de los planes de Estudios
# ¡Claro! A continuación, te proporciono una revisión general de las temáticas comunes que suelen incluirse en los planes de estudios de cursos o asignaturas relacionados con el Razonamiento Cuantitativo (Quantitative Reasoning). Estas temáticas pueden variar dependiendo del enfoque de la universidad (ciencias sociales, negocios, ingeniería, etc.), pero en general, abarcan habilidades matemáticas, analíticas y de resolución de problemas.
#
# 1. Fundamentos Matemáticos
# Aritmética básica: Operaciones con números enteros, fracciones, decimales y porcentajes.
#
# Álgebra elemental: Resolución de ecuaciones y desigualdades, funciones lineales y cuadráticas.
#
# Geometría básica: Cálculo de áreas, volúmenes y propiedades de figuras geométricas.
#
# Matemáticas financieras: Interés simple y compuesto, amortizaciones, valor presente y futuro.
#
# 2. Análisis de Datos
# Estadística descriptiva: Medidas de tendencia central (media, mediana, moda) y dispersión (rango, varianza, desviación estándar).
#
# Visualización de datos: Gráficos (barras, líneas, histogramas) y tablas para representar información.
#
# Probabilidad básica: Conceptos de probabilidad, eventos independientes y dependientes, distribuciones de probabilidad.
#
# 3. Pensamiento Crítico y Resolución de Problemas
# Interpretación de información cuantitativa: Análisis de gráficos, tablas y textos con datos numéricos.
#
# Argumentación basada en datos: Uso de evidencia cuantitativa para sustentar conclusiones.
#
# Toma de decisiones: Aplicación de herramientas cuantitativas para resolver problemas en contextos reales.
#
# 4. Herramientas Computacionales
# Software estadístico: Uso de programas como Excel, R, Python o SPSS para análisis de datos.
#
# Hojas de cálculo: Organización y manipulación de datos numéricos.
#
# Programación básica: Introducción a lenguajes como Python para automatizar cálculos y análisis.
#
# 5. Aplicaciones en Contextos Reales
# Ciencias sociales: Análisis de encuestas, estudios demográficos y tendencias sociales.
#
# Negocios y economía: Análisis financiero, proyecciones de ventas, optimización de recursos.
#
# Ciencias naturales y ambientales: Modelado de fenómenos naturales, análisis de datos experimentales.
#
# Salud pública: Interpretación de datos epidemiológicos, estudios de prevalencia.
#
# 6. Lógica y Razonamiento Formal
# Lógica matemática: Proposiciones, conectores lógicos, tablas de verdad.
#
# Razonamiento deductivo e inductivo: Inferencias a partir de premisas y datos.
#
# Argumentación lógica: Identificación de falacias y construcción de argumentos válidos.
#
# 7. Métodos Cuantitativos Avanzados (en niveles superiores)
# Estadística inferencial: Pruebas de hipótesis, intervalos de confianza, regresión lineal.
#
# Cálculo básico: Límites, derivadas e integrales aplicados a problemas prácticos.
#
# Optimización: Uso de técnicas matemáticas para maximizar o minimizar funciones.
#
# 8. Ética y Responsabilidad en el Uso de Datos
# Privacidad y seguridad de datos: Consideraciones éticas en la recopilación y análisis de información.
#
# Sesgos en los datos: Identificación y mitigación de errores sistemáticos en análisis cuantitativos.
#
# Comunicación efectiva de resultados: Presentación clara y honesta de hallazgos cuantitativos.
#
# 9. Proyectos Prácticos y Aplicaciones
# Casos de estudio: Análisis de problemas del mundo real utilizando herramientas cuantitativas.
#
# Proyectos integradores: Desarrollo de soluciones basadas en datos para problemas específicos.
#
# Simulaciones y modelado: Uso de modelos matemáticos para predecir resultados.
#
# 10. Evaluación y Retroalimentación
# Exámenes y pruebas: Evaluación de conceptos teóricos y habilidades prácticas.
#
# Trabajos y proyectos: Aplicación de conocimientos en contextos reales.
#
# Retroalimentación continua: Mejora de habilidades a través de revisiones y tutorías.
#
# Enfoques por Área de Estudio
# Ciencias Sociales: Mayor énfasis en estadística, probabilidad y análisis de encuestas.
#
# Negocios y Economía: Enfoque en matemáticas financieras, optimización y proyecciones.
#
# Ingeniería y Ciencias Naturales: Uso de cálculo, modelado y herramientas computacionales.
#
# Educación General: Desarrollo de habilidades básicas para la vida cotidiana y profesional.
#
# Esta revisión general te da una idea de las temáticas que podrías encontrar en los planes de estudios de Razonamiento Cuantitativo. Si necesitas detalles específicos de alguna universidad o programa, no dudes en preguntar. 😊
#
# Me lo puedes hacer por UNiversidad
# ¡Por supuesto! A continuación, te proporciono una revisión de las temáticas específicas que se abordan en los cursos de Razonamiento Cuantitativo (Quantitative Reasoning) en algunas universidades destacadas de Europa, Asia, América Latina y Estados Unidos. Estas temáticas están basadas en los planes de estudio disponibles públicamente o en la orientación general de cada institución.
#
# Europa
# 1. University of Cambridge (Reino Unido)
# Temáticas principales:
#
# Fundamentos de matemáticas aplicadas.
#
# Estadística descriptiva e inferencial.
#
# Análisis de datos en ciencias sociales.
#
# Uso de software como R y Python para análisis cuantitativo.
#
# Enfoque: Preparación para investigación en economía y ciencias sociales.
#
# 2. University of Oxford (Reino Unido)
# Temáticas principales:
#
# Lógica matemática y razonamiento formal.
#
# Métodos cuantitativos en filosofía y ciencias políticas.
#
# Interpretación de datos y gráficos.
#
# Enfoque: Desarrollo de habilidades analíticas para toma de decisiones.
#
# 3. ETH Zurich (Suiza)
# Temáticas principales:
#
# Cálculo y álgebra lineal aplicada.
#
# Modelado matemático en ingeniería.
#
# Optimización y simulación numérica.
#
# Enfoque: Aplicaciones en ingeniería y ciencias naturales.
#
# Asia
# 1. National University of Singapore (NUS) (Singapur)
# Temáticas principales:
#
# Estadística y probabilidad aplicada a negocios.
#
# Análisis de datos con Excel y Python.
#
# Matemáticas financieras y proyecciones.
#
# Enfoque: Preparación para carreras en negocios y economía.
#
# 2. University of Tokyo (Japón)
# Temáticas principales:
#
# Métodos cuantitativos en ciencias naturales.
#
# Modelado de fenómenos físicos y biológicos.
#
# Uso de software especializado (MATLAB, Python).
#
# Enfoque: Investigación en ingeniería y ciencias.
#
# 3. Tsinghua University (China)
# Temáticas principales:
#
# Matemáticas aplicadas a la economía.
#
# Análisis de big data y machine learning.
#
# Optimización de recursos en ingeniería.
#
# Enfoque: Aplicaciones en tecnología y negocios.
#
# América Latina
# 1. Universidad Nacional Autónoma de México (UNAM) (México)
# Temáticas principales:
#
# Estadística básica y probabilidad.
#
# Análisis de datos en ciencias sociales.
#
# Uso de Excel y SPSS para análisis cuantitativo.
#
# Enfoque: Formación general en habilidades cuantitativas.
#
# 2. Universidad de Buenos Aires (UBA) (Argentina)
# Temáticas principales:
#
# Matemáticas financieras y economía cuantitativa.
#
# Métodos estadísticos para investigación social.
#
# Interpretación de datos en salud pública.
#
# Enfoque: Aplicaciones en economía y ciencias sociales.
#
# 3. Pontificia Universidad Católica de Chile (UC) (Chile)
# Temáticas principales:
#
# Razonamiento lógico-matemático.
#
# Análisis de datos con herramientas computacionales.
#
# Aplicaciones en ingeniería y negocios.
#
# Enfoque: Desarrollo de habilidades prácticas para profesionales.
#
# Estados Unidos
# 1. Harvard University (Massachusetts)
# Temáticas principales:
#
# Pensamiento crítico basado en datos.
#
# Estadística aplicada a ciencias sociales.
#
# Uso de R y Python para análisis cuantitativo.
#
# Enfoque: Educación general para toma de decisiones informadas.
#
# 2. Stanford University (California)
# Temáticas principales:
#
# Matemáticas aplicadas a la computación.
#
# Análisis de big data y machine learning.
#
# Optimización en ingeniería y negocios.
#
# Enfoque: Preparación para carreras en tecnología y emprendimiento.
#
# 3. Massachusetts Institute of Technology (MIT) (Massachusetts)
# Temáticas principales:
#
# Cálculo y álgebra lineal avanzada.
#
# Modelado matemático en ingeniería.
#
# Simulación y análisis numérico.
#
# Enfoque: Investigación y aplicaciones en ciencias e ingeniería.
#
# 4. University of Chicago (Illinois)
# Temáticas principales:
#
# Métodos cuantitativos en economía.
#
# Análisis de datos en ciencias políticas.
#
# Uso de software estadístico (Stata, R).
#
# Enfoque: Investigación en ciencias sociales y economía.
#
# 5. Columbia University (Nueva York)
# Temáticas principales:
#
# Razonamiento cuantitativo en negocios.
#
# Análisis de datos financieros.
#
# Uso de Excel y Python para modelado.
#
# Enfoque: Preparación para carreras en finanzas y administración.
#
# Resumen por Región
# Europa: Enfoque en investigación y aplicaciones en ciencias sociales e ingeniería.
#
# Asia: Énfasis en tecnología, big data y aplicaciones en negocios.
#
# América Latina: Formación general en habilidades cuantitativas para ciencias sociales y economía.
#
# Estados Unidos: Combinación de educación general y aplicaciones avanzadas en tecnología, negocios e ingeniería.
#
# Si necesitas detalles más específicos de alguna universidad en particular, ¡no dudes en pedírmelo! 😊
#
# New chat

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ¡Perfecto! Vamos a integrar la competencia de **Interpretación y representación** en la propuesta, ubicándola en la unidad y temática más adecuada. Esta competencia se enfoca en la capacidad de los estudiantes para comprender y transformar información cuantitativa presentada en distintos formatos, como series, gráficas, tablas y esquemas. Aquí te muestro cómo la incorporamos:
#
# ---
#
# ### **Unidad 1: Fundamentos del Razonamiento Numérico (16 horas)**
#
# #### **1. Números y operaciones básicas (6 horas)**
#    - **Enteros, fracciones, decimales**:
#      - **Ejemplo 1**: Calcular el presupuesto mensual de una organización sin fines de lucro, distribuyendo los gastos en categorías (alimentos, transporte, servicios).
#      - **Ejemplo 2**: Convertir fracciones a decimales para analizar estadísticas de participación ciudadana en elecciones (por ejemplo, 3/4 de los votantes asistieron a las urnas).
#    - **Porcentajes**:
#      - **Ejemplo 1**: Calcular el porcentaje de aumento en el costo de vida en una ciudad durante los últimos 5 años.
#      - **Ejemplo 2**: Determinar el descuento aplicado a una beca estudiantil (por ejemplo, 20% de descuento en la matrícula).
#
# #### **2. Razones y proporciones (6 horas)**
#    - **Concepto de razón y proporción**:
#      - **Ejemplo 1**: Analizar la proporción de hombres y mujeres en un estudio de género (por ejemplo, 2:1).
#      - **Ejemplo 2**: Usar la regla de tres para calcular cuántos recursos se necesitan para alimentar a un grupo de personas en un evento comunitario.
#    - **Aplicaciones**:
#      - **Ejemplo 1**: Interpretar escalas en mapas para calcular distancias reales entre ciudades.
#      - **Ejemplo 2**: Ajustar una receta de cocina para un número diferente de comensales (por ejemplo, duplicar los ingredientes).
#
# #### **3. Potencias, raíces y jerarquía de operaciones (4 horas)**
#    - **Cálculo de potencias y raíces**:
#      - **Ejemplo 1**: Calcular el crecimiento exponencial de la población de una ciudad en 10 años.
#      - **Ejemplo 2**: Usar raíces cuadradas para determinar la desviación estándar en un estudio sociológico.
#    - **Jerarquía de operaciones**:
#      - **Ejemplo 1**: Resolver expresiones aritméticas para calcular el presupuesto anual de un proyecto social.
#    - **Notación científica**:
#      - **Ejemplo 1**: Expresar en notación científica el número de personas que viven en pobreza extrema en un país.
#
# ---
#
# ### **Unidad 2: Resolución de Problemas y Modelado Matemático (16 horas)**
#
# #### **1. Estrategias para la resolución de problemas (4 horas)**
#    - **Identificación de datos relevantes**:
#      - **Ejemplo 1**: Analizar datos de una encuesta sobre preferencias políticas para identificar tendencias.
#      - **Ejemplo 2**: Plantear una ecuación para calcular el número de libros que se pueden comprar con un presupuesto limitado.
#    - **Resolución de problemas en grupos**:
#      - **Ejemplo 1**: Trabajar en equipo para resolver un problema de distribución de recursos en una comunidad.
#
# #### **2. Problemas de proporcionalidad, porcentajes y descuentos (6 horas)**
#    - **Aplicación de la regla de tres**:
#      - **Ejemplo 1**: Calcular cuántas personas pueden ser atendidas en un hospital con un número limitado de camas.
#    - **Cálculo de descuentos e impuestos**:
#      - **Ejemplo 1**: Determinar el precio final de un libro después de aplicar un descuento del 15%.
#    - **Análisis de casos**:
#      - **Ejemplo 1**: Resolver un problema de presupuesto para un proyecto de investigación social.
#
# #### **3. Problemas de interés simple y modelado básico (6 horas)**
#    - **Cálculo de interés simple**:
#      - **Ejemplo 1**: Calcular el interés generado por un préstamo para un proyecto comunitario.
#    - **Planteamiento de ecuaciones simples**:
#      - **Ejemplo 1**: Representar mediante una ecuación el crecimiento de la membresía de una organización sin fines de lucro.
#    - **Ejercicios prácticos**:
#      - **Ejemplo 1**: Resolver un problema de inversión para financiar una campaña de concientización social.
#
# ---
#
# ### **Unidad 3: Razonamiento Lógico-Matemático (16 horas)**
#
# #### **1. Series numéricas y patrones (4 horas)**
#    - **Identificación de patrones**:
#      - **Ejemplo 1**: Identificar patrones en datos históricos de participación electoral.
#    - **Predicción de términos futuros**:
#      - **Ejemplo 1**: Predecir la asistencia a un evento cultural basándose en datos de años anteriores.
#
# #### **2. Problemas de lógica y razonamiento deductivo (6 horas)**
#    - **Resolución de acertijos y problemas de lógica**:
#      - **Ejemplo 1**: Resolver un acertijo sobre la distribución de recursos en una comunidad.
#    - **Planteamiento de inferencias y deducciones lógicas**:
#      - **Ejemplo 1**: Analizar un argumento político y determinar si las conclusiones son válidas.
#    - **Análisis de argumentos y detección de falacias**:
#      - **Ejemplo 1**: Identificar falacias en un discurso público.
#
# #### **3. Interpretación y representación (4 horas)**
#    - **Comprensión de información cuantitativa**:
#      - **Ejemplo 1**: Interpretar una gráfica de barras que muestra el nivel de educación en diferentes regiones de un país.
#      - **Ejemplo 2**: Analizar una tabla de datos sobre el desempleo en los últimos 10 años.
#    - **Transformación de información**:
#      - **Ejemplo 1**: Convertir datos numéricos en un gráfico de líneas para mostrar tendencias de crecimiento económico.
#      - **Ejemplo 2**: Crear un esquema que resuma los resultados de una encuesta sobre preferencias políticas.
#
# #### **4. Interpretación de enunciados y planteamiento de inferencias (2 horas)**
#    - **Análisis de enunciados complejos**:
#      - **Ejemplo 1**: Identificar premisas y conclusiones en un texto sobre políticas públicas.
#    - **Desarrollo de habilidades para la argumentación lógica**:
#      - **Ejemplo 1**: Construir un argumento lógico para defender una postura en un debate sobre educación.
#
# ---
#
# ### **Resumen de Ejemplos por Unidad**
# - **Unidad 1**: Presupuestos, estadísticas, escalas, crecimiento poblacional.
# - **Unidad 2**: Encuestas, distribución de recursos, préstamos, proyectos sociales.
# - **Unidad 3**: Patrones electorales, argumentos políticos, interpretación de gráficas y tablas, debates.
#
# ---
#
# ### **Ubicación de la Competencia de Interpretación y Representación**
# La competencia de **Interpretación y representación** se ha integrado en la **Unidad 3**, dentro de la sección **3. Interpretación y representación (4 horas)**. Esta ubicación es ideal porque:
# 1. **Coherencia temática**: El razonamiento lógico-matemático incluye habilidades de análisis y representación de información.
# 2. **Aplicación práctica**: Los estudiantes pueden aplicar lo aprendido en las unidades anteriores (números, proporciones, resolución de problemas) para interpretar y transformar datos en formatos visuales.
# 3. **Relevancia para Ciencias Sociales**: La interpretación de gráficas, tablas y esquemas es fundamental en áreas como sociología, economía y política.
#
# ---
#
# Si necesitas más ajustes o ejemplos adicionales, ¡no dudes en pedírmelo! 😊

# %% [markdown]
# ¡Excelente idea! A continuación, te propongo **ejemplos específicos** para cada una de las carreras mencionadas, integrando las temáticas de **Razonamiento Cuantitativo** y la competencia de **Interpretación y representación**. Estos ejemplos están diseñados para ser relevantes y prácticos, conectando las habilidades cuantitativas con las necesidades de cada disciplina.
#
# ---
#
# ### **1. Arquitectura**
#    - **Interpretación de gráficas y tablas**:
#      - **Ejemplo 1**: Analizar una gráfica de costos de materiales de construcción (acero, cemento, vidrio) para tomar decisiones sobre el presupuesto de un proyecto.
#      - **Ejemplo 2**: Interpretar una tabla de datos sobre el consumo energético de diferentes tipos de edificios para diseñar estructuras sostenibles.
#    - **Aplicación de proporciones y escalas**:
#      - **Ejemplo 1**: Usar la regla de tres para calcular las dimensiones reales de un edificio a partir de un plano a escala.
#      - **Ejemplo 2**: Determinar la proporción de espacios verdes en un diseño urbano para cumplir con normativas ambientales.
#
# ---
#
# ### **2. Diseño**
#    - **Interpretación de datos visuales**:
#      - **Ejemplo 1**: Analizar una gráfica de tendencias de colores en diseño de interiores para proponer paletas actualizadas.
#      - **Ejemplo 2**: Interpretar una tabla de preferencias de usuarios sobre diseños de productos para mejorar la usabilidad.
#    - **Aplicación de porcentajes y razones**:
#      - **Ejemplo 1**: Calcular el porcentaje de reducción de material en un diseño eco-friendly.
#      - **Ejemplo 2**: Usar proporciones para distribuir espacios en un diseño gráfico (por ejemplo, la relación entre texto e imágenes en un póster).
#
# ---
#
# ### **3. Administración de Empresas**
#    - **Interpretación de gráficas financieras**:
#      - **Ejemplo 1**: Analizar una gráfica de ventas mensuales para identificar tendencias y planificar estrategias de marketing.
#      - **Ejemplo 2**: Interpretar una tabla de costos fijos y variables para calcular el punto de equilibrio de una empresa.
#    - **Aplicación de porcentajes y descuentos**:
#      - **Ejemplo 1**: Calcular descuentos en una campaña de promociones para maximizar las ventas.
#      - **Ejemplo 2**: Determinar el porcentaje de crecimiento anual de una empresa a partir de datos históricos.
#
# ---
#
# ### **4. Finanzas y Negocios Internacionales**
#    - **Interpretación de datos económicos**:
#      - **Ejemplo 1**: Analizar una gráfica de fluctuaciones en el tipo de cambio para tomar decisiones de inversión.
#      - **Ejemplo 2**: Interpretar una tabla de datos sobre el PIB de diferentes países para evaluar oportunidades de negocio.
#    - **Aplicación de interés simple y compuesto**:
#      - **Ejemplo 1**: Calcular el interés generado por una inversión en bonos internacionales.
#      - **Ejemplo 2**: Determinar el valor futuro de una inversión en divisas extranjeras.
#
# ---
#
# ### **5. Contaduría Pública**
#    - **Interpretación de estados financieros**:
#      - **Ejemplo 1**: Analizar una gráfica de flujo de caja para evaluar la liquidez de una empresa.
#      - **Ejemplo 2**: Interpretar una tabla de balances generales para identificar tendencias en los activos y pasivos.
#    - **Aplicación de porcentajes y proporciones**:
#      - **Ejemplo 1**: Calcular el porcentaje de impuestos sobre la renta para una declaración fiscal.
#      - **Ejemplo 2**: Determinar la proporción de gastos operativos en relación con los ingresos totales.
#
# ---
#
# ### **6. Derecho**
#    - **Interpretación de datos estadísticos**:
#      - **Ejemplo 1**: Analizar una gráfica de tasas de criminalidad para proponer políticas de seguridad pública.
#      - **Ejemplo 2**: Interpretar una tabla de datos sobre sentencias judiciales para identificar patrones en la aplicación de la ley.
#    - **Aplicación de porcentajes y razones**:
#      - **Ejemplo 1**: Calcular el porcentaje de casos resueltos favorablemente en un bufete de abogados.
#      - **Ejemplo 2**: Determinar la proporción de recursos aprobados en un presupuesto para el sistema judicial.
#
# ---
#
# ### **7. Psicología**
#    - **Interpretación de datos de encuestas**:
#      - **Ejemplo 1**: Analizar una gráfica de resultados de un test psicológico para evaluar el bienestar emocional de un grupo.
#      - **Ejemplo 2**: Interpretar una tabla de datos sobre preferencias de terapia en diferentes grupos de edad.
#    - **Aplicación de estadística descriptiva**:
#      - **Ejemplo 1**: Calcular la media y desviación estándar de los puntajes de un estudio sobre ansiedad.
#      - **Ejemplo 2**: Determinar la correlación entre horas de sueño y niveles de estrés en una muestra de pacientes.
#
# ---
#
# ### **8. Economía**
#    - **Interpretación de gráficas económicas**:
#      - **Ejemplo 1**: Analizar una gráfica de oferta y demanda para predecir cambios en los precios de un producto.
#      - **Ejemplo 2**: Interpretar una tabla de datos sobre inflación en diferentes países para evaluar políticas monetarias.
#    - **Aplicación de modelos matemáticos**:
#      - **Ejemplo 1**: Usar ecuaciones lineales para modelar el crecimiento económico de una región.
#      - **Ejemplo 2**: Calcular el impacto de un aumento salarial en la economía local.
#
# ---
#
# ### **Resumen de Ejemplos por Carrera**
# - **Arquitectura**: Costos de materiales, escalas, sostenibilidad.
# - **Diseño**: Tendencias de colores, usabilidad, diseño eco-friendly.
# - **Administración de Empresas**: Ventas, costos, punto de equilibrio.
# - **Finanzas y Negocios Internacionales**: Tipo de cambio, PIB, inversiones.
# - **Contaduría Pública**: Flujo de caja, impuestos, balances.
# - **Derecho**: Tasas de criminalidad, sentencias, presupuestos.
# - **Psicología**: Bienestar emocional, ansiedad, correlaciones.
# - **Economía**: Oferta y demanda, inflación, crecimiento económico.
#
# ---
#
# Esta propuesta asegura que los ejemplos sean **relevantes y aplicables** para cada carrera, conectando las habilidades cuantitativas con las necesidades específicas de cada disciplina. Si necesitas más ejemplos o ajustes, ¡avísame! 😊
